# %%
import os
import pandas as pd
from PIL import Image

# %%
input_dir = "/kaggle/input/blood-vessel-segmentation/"

# %% [markdown]
# ## Kidney_1_dense

# %%
k1_dense_path = f"{input_dir}train/kidney_1_dense/"
k1_dense_imgs = pd.Series(os.listdir(f"{k1_dense_path}images"))
# k1_dense_labels = pd.Series(os.listdir(f"{input_dir}/train/kidney_1_dense/labels"))
k1_dense_imgs
# Out:
# 0       1259.tif
# 1       2037.tif
# 2       0301.tif
# 3       1819.tif
# 4       0655.tif
#           ...
# 2274    0506.tif
# 2275    0612.tif
# 2276    0153.tif
# 2277    0065.tif
# 2278    0795.tif
# Length: 2279, dtype: object

# %%
k1_dense_imgs.value_counts()
# Out:
# 1259.tif    1
# 1318.tif    1
# 0260.tif    1
# 0213.tif    1
# 2017.tif    1
#            ..
# 1588.tif    1
# 1982.tif    1
# 0044.tif    1
# 1847.tif    1
# 0795.tif    1
# Name: count, Length: 2279, dtype: int64

# %%
k1_dense_imgs.sort_values()
# Out:
# 1399    0000.tif
# 901     0001.tif
# 1193    0002.tif
# 2139    0003.tif
# 1940    0004.tif
#           ...
# 619     2274.tif
# 1994    2275.tif
# 441     2276.tif
# 1283    2277.tif
# 1738    2278.tif
# Length: 2279, dtype: object

# %%
Image.open(k1_dense_path + "images/" + k1_dense_imgs[1])
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=I;16 size=912x1303>
